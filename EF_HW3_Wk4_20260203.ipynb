# %% [markdown]
# <a href="https://colab.research.google.com/github/EvanFusner/MIS2800/blob/main/EF_HW3_Wk4_20260203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Instructions**

# %%
# %%sql
# DROP TABLE IF EXISTS Marketing_Brands;
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# Done.
# []

# %% [markdown]
# Video https://www.loom.com/share/01ff9fb7642f4215803d741e6b5db91d
# The Below cells have errors preventing them from running
# correctly. Some have typos and some have missing text
# altogether. While AI can do many things for us - the ability to
# debug and troubleshoot is one of the most valuable skills you
# can learn.
# This document is provided to you as a PDF file. Your
# assignment is to run the code as shown successfully and
# answer the questions at the end of the document.
# The code to run the installations and imports are provided for
# you. Just be sure you type exactly as shown. Typos can be in
# the form of extra space or no space or not putting on
# separate lines.

# %% [markdown]
# To Complete for Credit
# 1. Fix the errors in the 10 blocks that have an error. A brief comment has been added
# to each one to provide guidance on what is missing.
# 2. Answer the questions at the end on how you fixed the errors.
# 3. Save file into GitHub and submit the GitHub link into ISMS.
# keyboard_arrow_down Instructions
# The next six blocks provide the exact code to run to get your Colab file
# started to run SQLite3.

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file
# started to run SQLite3.

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 68.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE IF NOT EXISTS Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget_amount INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketing_Brands table
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand types
SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
-- Instructions: Fix the code to display the brand names that have a budget over 5000000
SELECT brand_name FROM Marketing_Brands WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
#Block 7
# Instructions: Fix the code so that this will run SQLite3 in Colab without error
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is Snacks or Beverages
SELECT * FROM Marketing_Brands WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in DESC order. Display brand_name and brand_budget
SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a table showing all the columns
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# # Answer the Questions Below Based on the SQL Code
# # You've Run Above

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: Added the word table
# 2. How did you fix the error in Block #2? Answer: Added INTO Marketing_Brands
# 3. How did you fix the error in Block #3? Answer: Added * to columns
# 4. How did you fix the error in Block #4? Answer: Specified brand name & type
# 5. How did you fix the error in Block #5? Answer: Added where clause for filter for 'Religous' brands
# 6. How did you fix the error in Block #6? Answer: Added where clause for filter for budgets greater than 5,000,000
# 7. How did you fix the error in Block #7? Answer:Added %%SQL magic command
# 8. How did you fix the error in Block #8? Answer: Added a WHERE clause for S&B
# 9. How did you fix the error in Block #9? Answer: Added ORDER BY Brand Budget_DESC
# 10. How did you fix the error in Block #10? Answer: Added the %%SQL magic and a SELECT * statement to display table
